# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Ahmed\git\\HACKER_RANK\Machine learning\\sentdex course\\Data Analysis with Python and Pandas Sentdex\\avocado.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %%
df['Date'] = pd.to_datetime(df["Date"])

# %%
df['Date']
# Out:
# 0       2015-12-27
# 1       2015-12-20
# 2       2015-12-13
# 3       2015-12-06
# 4       2015-11-29
#            ...
# 18244   2018-02-04
# 18245   2018-01-28
# 18246   2018-01-21
# 18247   2018-01-14
# 18248   2018-01-07
# Name: Date, Length: 18249, dtype: datetime64[ns]

# %%
df.set_index('Date', inplace=True)

# %%
df.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2015-12-13           2          0.93     118220.22   794.70  109149.67
# 2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 2015-11-29           4          1.28      51039.60   941.48   43838.39
#
#               4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27   48.16     8696.87     8603.62       93.25          0.0
# 2015-12-20   58.33     9505.56     9408.07       97.49          0.0
# 2015-12-13  130.50     8145.35     8042.21      103.14          0.0
# 2015-12-06   72.58     5811.16     5677.40      133.76          0.0
# 2015-11-29   75.78     6183.95     5986.26      197.69          0.0
#
#                     type  year  region
# Date
# 2015-12-27  conventional  2015  Albany
# ...

# %%
albany_df = df[df['region']=='Albany']

# %%
albany_df['region'].value_counts()
# Out:
# Albany    338
# Name: region, dtype: int64

# %%
df['region'].value_counts()
# Out:
# Detroit                338
# California             338
# Southeast              338
# TotalUS                338
# Tampa                  338
# Boise                  338
# Albany                 338
# SouthCentral           338
# Plains                 338
# Charlotte              338
# Sacramento             338
# BaltimoreWashington    338
# Pittsburgh             338
# Atlanta                338
# Spokane                338
# NewYork                338
# Portland               338
# LosAngeles             338
# MiamiFtLauderdale      338
# NewOrleansMobile       338
# Roanoke                338
# West                   338
# HarrisburgScranton     338
# Denver                 338
# Philadelphia           338
# SanDiego               338
# Orlando                338
# Louisville             338
# LasVegas               338
# RichmondNorfolk        338
# SanFrancisco           338
# Syracuse               338
# SouthCarolina          338
# Indianapolis           338
# ...

# %%
len(df['region'])
# Out:
# 18249

# %%
df['region'].value_counts().sum()
# Out:
# 18249

# %%
df['AveragePrice'].plot(figsize=(20,15))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2015-12-13           2          0.93     118220.22   794.70  109149.67
# 2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 2015-11-29           4          1.28      51039.60   941.48   43838.39
# ...                ...           ...           ...      ...        ...
# 2018-02-04           7          1.63      17074.83  2046.96    1529.20
# 2018-01-28           8          1.71      13888.04  1191.70    3431.50
# 2018-01-21           9          1.87      13766.76  1191.92    2452.79
# 2018-01-14          10          1.93      16205.22  1527.63    2981.04
# 2018-01-07          11          1.62      17489.58  2894.77    2356.13
#
#               4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# ...

# %%
df.sort_index(inplace=True)

# %%
df['AveragePrice'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Second lesson of pandas series
import pandas as pd

# %%
df = pd.read_csv("C:\\Ahmed\git\\HACKER_RANK\Machine learning\\sentdex course\\Data Analysis with Python and Pandas Sentdex\\avocado.csv")

# %%
albany_df = df[df['region']=="Albany"]
albany_df.set_index("Date", inplace=True)

albany_df["AveragePrice"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
albany_df.sort_index(inplace=True)
# Out:
# <ipython-input-5-d3fae3b3e118>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   albany_df.sort_index(inplace=True)

# %%
albany_df["AveragePrice"].rolling(25).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
albany_df["AveragePrice"].rolling(25).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
albany_df["price25ma"] = albany_df["AveragePrice"].rolling(25).mean()
# Out:
# <ipython-input-8-c1f362f23412>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   albany_df["price25ma"] = albany_df["AveragePrice"].rolling(25).mean()

# %%
df['region']
# Out:
# 0                  Albany
# 1                  Albany
# 2                  Albany
# 3                  Albany
# 4                  Albany
#                ...
# 18244    WestTexNewMexico
# 18245    WestTexNewMexico
# 18246    WestTexNewMexico
# 18247    WestTexNewMexico
# 18248    WestTexNewMexico
# Name: region, Length: 18249, dtype: object

# %%
df['region'].values
# Out:
# array(['Albany', 'Albany', 'Albany', ..., 'WestTexNewMexico',
#        'WestTexNewMexico', 'WestTexNewMexico'], dtype=object)

# %%
df['region'].values.tolist()
# Out:
# ['Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
# ...

# %%
print(set(df['region'].values.tolist()))
# Out:
# {'Denver', 'LosAngeles', 'RaleighGreensboro', 'LasVegas', 'DallasFtWorth', 'Detroit', 'NorthernNewEngland', 'Pittsburgh', 'Sacramento', 'NewYork', 'BuffaloRochester', 'SanFrancisco', 'Midsouth', 'PhoenixTucson', 'Syracuse', 'California', 'HartfordSpringfield', 'HarrisburgScranton', 'West', 'GrandRapids', 'Nashville', 'Boston', 'StLouis', 'Indianapolis', 'Houston', 'Orlando', 'RichmondNorfolk', 'SanDiego', 'Spokane', 'Jacksonville', 'Portland', 'Charlotte', 'WestTexNewMexico', 'Atlanta', 'SouthCarolina', 'SouthCentral', 'Roanoke', 'Tampa', 'Southeast', 'Northeast', 'Seattle', 'MiamiFtLauderdale', 'Plains', 'NewOrleansMobile', 'Chicago', 'Columbus', 'BaltimoreWashington', 'GreatLakes', 'Louisville', 'Boise', 'CincinnatiDayton', 'TotalUS', 'Albany', 'Philadelphia'}

# %%
df['region'].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
graph_df = pd.DataFrame()

for region in df['region'].unique()[:16]:
    region_df = df.copy()[df['region']==region]
    region_df.set_index('Date', inplace=True)
    region_df.sort_index(inplace=True)
    region_df[f"{region}_price25ma"] = region_df["AveragePrice"].rolling(25).mean()

    if graph_df.empty:
        graph_df = region_df[[f"{region}_price25ma"]]  # note the double square brackets! (so df rather than series)
    else:
        graph_df = graph_df.join(region_df[f"{region}_price25ma"])

graph_df.tail()
# Out:
#             Albany_price25ma  Atlanta_price25ma  \
# Date
# 2018-03-25            1.4368             1.2884
# 2018-03-25            1.4368             1.2884
# 2018-03-25            1.4368             1.2884
# 2018-03-25            1.4368             1.2884
# 2018-03-25            1.4368             1.2884
#
#             BaltimoreWashington_price25ma  Boise_price25ma  Boston_price25ma  \
# Date
# 2018-03-25                         1.3844           1.5016             1.588
# 2018-03-25                         1.3844           1.5016             1.588
# 2018-03-25                         1.3844           1.5016             1.588
# 2018-03-25                         1.3844           1.5016             1.588
# 2018-03-25                         1.3844           1.5016             1.588
#
#             BuffaloRochester_price25ma  California_price25ma  \
# Date
# 2018-03-25                      1.2232                1.4232
# 2018-03-25                      1.2232                1.4232
# ...

# %%
graph_df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
# Error in callback <function flush_figures at 0x0000021FA0CBBC10> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...
