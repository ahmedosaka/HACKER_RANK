# %%
# location of the US minimum wage file 
# C:\\Ahmed\\git\\HACKER_RANK\\Machine learning\\sentdex course\\Data Analysis with Python and Pandas Sentdex\\US Minimum Wage\\Minimum Wage Data.csv

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Ahmed\\git\\HACKER_RANK\\Machine learning\\sentdex course\\Data Analysis with Python and Pandas Sentdex\\US Minimum Wage\\Minimum Wage Data.csv", encoding="latin")

# %%
df.head()
# Out:
#    Year       State  State.Minimum.Wage  State.Minimum.Wage.2020.Dollars  \
# 0  1968     Alabama             0.00000                             0.00
# 1  1968      Alaska             2.10000                            15.61
# 2  1968     Arizona             0.46800                             3.48
# 3  1968    Arkansas             0.15625                             1.16
# 4  1968  California             1.65000                            12.26
#
#    Federal.Minimum.Wage  Federal.Minimum.Wage.2020.Dollars  \
# 0                  1.15                               8.55
# 1                  1.15                               8.55
# 2                  1.15                               8.55
# 3                  1.15                               8.55
# 4                  1.15                               8.55
#
#    Effective.Minimum.Wage  Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 0                    1.15                                 8.55         34.8
# ...

# %%
df.to_csv("C:\\Ahmed\\git\\HACKER_RANK\\Machine learning\\sentdex course\\Data Analysis with Python and Pandas Sentdex\\US Minimum Wage\\minwage.csv", encoding="utf-8")
df = pd.read_csv("C:\\Ahmed\\git\\HACKER_RANK\\Machine learning\\sentdex course\\Data Analysis with Python and Pandas Sentdex\\US Minimum Wage\\minwage.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Year       State  State.Minimum.Wage  \
# 0           0  1968     Alabama             0.00000
# 1           1  1968      Alaska             2.10000
# 2           2  1968     Arizona             0.46800
# 3           3  1968    Arkansas             0.15625
# 4           4  1968  California             1.65000
#
#    State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                             0.00                  1.15
# 1                            15.61                  1.15
# 2                             3.48                  1.15
# 3                             1.16                  1.15
# 4                            12.26                  1.15
#
#    Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                               8.55                    1.15
# 1                               8.55                    2.10
# 2                               8.55                    1.15
# ...

# %%
gb = df.groupby("State")
gb.get_group("Alabama").set_index("Year").head()
# Out:
#       Unnamed: 0    State  State.Minimum.Wage  \
# Year
# 1968           0  Alabama                 0.0
# 1969          54  Alabama                 0.0
# 1970         108  Alabama                 0.0
# 1971         162  Alabama                 0.0
# 1972         216  Alabama                 0.0
#
#       State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# Year
# 1968                              0.0                  1.15
# 1969                              0.0                  1.15
# 1970                              0.0                  1.30
# 1971                              0.0                  1.30
# 1972                              0.0                  1.60
#
#       Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# Year
# 1968                               8.55                    1.15
# 1969                               8.11                    1.15
# 1970                               8.67                    1.30
# ...

# %%
act_min_wage = pd.DataFrame()

for name, group in df.groupby("State"):
    if act_min_wage.empty:
        act_min_wage = group.set_index("Year")[["Low.2018"]].rename(columns={"Low.2018":name})
    else:
        act_min_wage = act_min_wage.join(group.set_index("Year")[["Low.2018"]].rename(columns={"Low.2018":name}))

act_min_wage.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-0e3d03ed99b2> in <module>
#       3 for name, group in df.groupby("State"):
#       4     if act_min_wage.empty:
# ----> 5         act_min_wage = group.set_index("Year")[["Low.2018"]].rename(columns={"Low.2018":name})
#       6     else:
#       7         act_min_wage = act_min_wage.join(group.set_index("Year")[["Low.2018"]].rename(columns={"Low.2018":name}))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Year       State  State.Minimum.Wage  \
# 0           0  1968     Alabama             0.00000
# 1           1  1968      Alaska             2.10000
# 2           2  1968     Arizona             0.46800
# 3           3  1968    Arkansas             0.15625
# 4           4  1968  California             1.65000
#
#    State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                             0.00                  1.15
# 1                            15.61                  1.15
# 2                             3.48                  1.15
# 3                             1.16                  1.15
# 4                            12.26                  1.15
#
#    Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                               8.55                    1.15
# 1                               8.55                    2.10
# 2                               8.55                    1.15
# ...
